# %%
import numpy as np
import matplotlib.pyplot as plt

# Setup latex in matplotlib
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')

import matplotlib.font_manager as fm

# Make everything bold
prop = fm.FontProperties(weight='bold', size=8)


# # Setup plot params for IEEE figures
plt.rcParams['font.size'] = 10
plt.rcParams['axes.titlesize'] = 10
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['lines.linewidth'] = 2.5
plt.rcParams['lines.markersize'] = 6
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.labelpad'] = 3
plt.rcParams['axes.titlepad'] = 3
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.alpha'] = 0.5

# Increase dpi
plt.rcParams['figure.dpi'] = 300

# %%
## Single label results
# 15%
# Load data for Sparsemax
Single_sparsemax_val_loss_15 = np.load('./15%/Single_label/Final_models/Sparsemax/val_loss_sparsemax_15.npy')
Single_sparsemax_val_accuracy_15 = np.load('./15%/Single_label/Final_models/Sparsemax/val_accuracy_sparsemax_15.npy')
Single_sparsemax_train_loss_15 = np.load('./15%/Single_label/Final_models/Sparsemax/train_loss_sparsemax_15.npy')
Single_sparsemax_train_accuracy_15 = np.load('./15%/Single_label/Final_models/Sparsemax/train_accuracy_sparsemax_15.npy')

# Load data for RST
Single_RST_val_loss_15 = np.load('./15%/Single_label/Final_models/RST/val_loss_RST_15.npy')
Single_RST_val_accuracy_15 = np.load('./15%/Single_label/Final_models/RST/val_accuracy_RST_15.npy')
Single_RST_train_loss_15 = np.load('./15%/Single_label/Final_models/RST/train_loss_RST_15.npy')
Single_RST_train_accuracy_15 = np.load('./15%/Single_label/Final_models/RST/train_accuracy_RST_15.npy')

# Load data for Softmax
Single_softmax_val_loss_15 = np.load('./15%/Single_label/Final_models/Softmax/val_loss_softmax_15.npy')
Single_softmax_val_accuracy_15 = np.load('./15%/Single_label/Final_models/Softmax/val_accuracy_softmax_15.npy')
Single_softmax_train_loss_15 = np.load('./15%/Single_label/Final_models/Softmax/train_loss_softmax_15.npy')
Single_softmax_train_accuracy_15 = np.load('./15%/Single_label/Final_models/Softmax/train_accuracy_softmax_15.npy')

# 5%
# Load data for Sparsemax
Single_sparsemax_val_loss_5 = np.load('./5%/Single_label/Final_models/Sparsemax/val_loss_sparsemax_5.npy')
Single_sparsemax_val_accuracy_5 = np.load('./5%/Single_label/Final_models/Sparsemax/val_accuracy_sparsemax_5.npy')
Single_sparsemax_train_loss_5 = np.load('./5%/Single_label/Final_models/Sparsemax/train_loss_sparsemax_5.npy')
Single_sparsemax_train_accuracy_5 = np.load('./5%/Single_label/Final_models/Sparsemax/train_accuracy_sparsemax_5.npy')
# Load data for RST
Single_RST_val_loss_5 = np.load('./5%/Single_label/Final_models/RST/val_loss_RST_5.npy')
Single_RST_val_accuracy_5 = np.load('./5%/Single_label/Final_models/RST/val_accuracy_RST_5.npy')
Single_RST_train_loss_5 = np.load('./5%/Single_label/Final_models/RST/train_loss_RST_5.npy')
Single_RST_train_accuracy_5 = np.load('./5%/Single_label/Final_models/RST/train_accuracy_RST_5.npy')
# Load data for Softmax
Single_softmax_val_loss_5 = np.load('./5%/Single_label/Final_models/Softmax/val_loss_softmax_5.npy')
Single_softmax_val_accuracy_5 = np.load('./5%/Single_label/Final_models/Softmax/val_accuracy_softmax_5.npy')
Single_softmax_train_loss_5 = np.load('./5%/Single_label/Final_models/Softmax/train_loss_softmax_5.npy')
Single_softmax_train_accuracy_5 = np.load('./5%/Single_label/Final_models/Softmax/train_accuracy_softmax_5.npy')

# %%
## Multi label results
# 15%
# Load data for Sparsemax
Multi_sparsemax_val_loss_15 = np.load('./15%/Multi_label/Final_models/Sparsemax/val_loss_sparsemax_15.npy')
Multi_sparsemax_val_accuracy_15 = np.load('./15%/Multi_label/Final_models/Sparsemax/val_accuracy_sparsemax_15.npy')
Multi_sparsemax_train_loss_15 = np.load('./15%/Multi_label/Final_models/Sparsemax/train_loss_sparsemax_15.npy')
Multi_sparsemax_train_accuracy_15 = np.load('./15%/Multi_label/Final_models/Sparsemax/train_accuracy_sparsemax_15.npy')
# Load data for RST
Multi_RST_val_loss_15 = np.load('./15%/Multi_label/Final_models/RST/val_loss_RST_15.npy')
Multi_RST_val_accuracy_15 = np.load('./15%/Multi_label/Final_models/RST/val_accuracy_RST_15.npy')
Multi_RST_train_loss_15 = np.load('./15%/Multi_label/Final_models/RST/train_loss_RST_15.npy')
Multi_RST_train_accuracy_15 = np.load('./15%/Multi_label/Final_models/RST/train_accuracy_RST_15.npy')
# Load data for Softmax
Multi_softmax_val_loss_15 = np.load('./15%/Multi_label/Final_models/Softmax/val_loss_softmax_15.npy')
Multi_softmax_val_accuracy_15 = np.load('./15%/Multi_label/Final_models/Softmax/val_accuracy_softmax_15.npy')
Multi_softmax_train_loss_15 = np.load('./15%/Multi_label/Final_models/Softmax/train_loss_softmax_15.npy')
Multi_softmax_train_accuracy_15 = np.load('./15%/Multi_label/Final_models/Softmax/train_accuracy_softmax_15.npy')
# 5%
# Load data for Sparsemax
Multi_sparsemax_val_loss_5 = np.load('./5%/Multi_label/Final_models/Sparsemax/val_loss_sparsemax_5.npy')
Multi_sparsemax_val_accuracy_5 = np.load('./5%/Multi_label/Final_models/Sparsemax/val_accuracy_sparsemax_5.npy')
Multi_sparsemax_train_loss_5 = np.load('./5%/Multi_label/Final_models/Sparsemax/train_loss_sparsemax_5.npy')
Multi_sparsemax_train_accuracy_5 = np.load('./5%/Multi_label/Final_models/Sparsemax/train_accuracy_sparsemax_5.npy')
# Load data for RST
Multi_RST_val_loss_5 = np.load('./5%/Multi_label/Final_models/RST/val_loss_RST_5.npy')
Multi_RST_val_accuracy_5 = np.load('./5%/Multi_label/Final_models/RST/val_accuracy_RST_5.npy')
Multi_RST_train_loss_5 = np.load('./5%/Multi_label/Final_models/RST/train_loss_RST_5.npy')
Multi_RST_train_accuracy_5 = np.load('./5%/Multi_label/Final_models/RST/train_accuracy_RST_5.npy')
# Load data for Softmax
Multi_softmax_val_loss_5 = np.load('./5%/Multi_label/Final_models/Softmax/val_loss_softmax_5.npy')
Multi_softmax_val_accuracy_5 = np.load('./5%/Multi_label/Final_models/Softmax/val_accuracy_softmax_5.npy')
Multi_softmax_train_loss_5 = np.load('./5%/Multi_label/Final_models/Softmax/train_loss_softmax_5.npy')
Multi_softmax_train_accuracy_5 = np.load('./5%/Multi_label/Final_models/Softmax/train_accuracy_softmax_5.npy')

# %%
## Plot results for single label 5% 15%

plt.plot(Single_sparsemax_val_loss_15, label=r'Sparsemax - 15%')
plt.plot(Single_sparsemax_val_loss_5, label=r'Sparsemax - 5%')
plt.plot(Single_RST_val_loss_15, label=r'RST - 15%')
plt.plot(Single_RST_val_loss_5, label=r'RST - 5%')
plt.plot(Single_softmax_val_loss_15, label=r'Softmax - 15%')
plt.plot(Single_softmax_val_loss_5, label=r'Softmax - 5%')
plt.title(r'Single Label Validation Loss - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Validation Loss $\longrightarrow$')
plt.legend(loc='best', prop= prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Single_label_val_loss_IEEE118.png')
plt.show()

# %%
## Plot results for Multi label 5% and 15%

plt.plot(Multi_sparsemax_val_loss_15, label=r'Sparsemax - 15%')
plt.plot(Multi_sparsemax_val_loss_5, label=r'Sparsemax - 5%')
plt.plot(Multi_RST_val_loss_15, label=r'RST - 15%')
plt.plot(Multi_RST_val_loss_5, label=r'RST - 5%')
plt.plot(Multi_softmax_val_loss_15, label=r'Softmax - 15%')
plt.plot(Multi_softmax_val_loss_5, label=r'Softmax - 5%')
plt.title(r'Multi Label Validation Loss - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Validation Loss $\longrightarrow$')
plt.legend(loc='best', prop=prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Multi_label_val_loss_IEEE118.png')
plt.show()

# %%
## Plot results for single label accuracy 5% 15%

plt.plot(Single_sparsemax_val_accuracy_15, label=r'Sparsemax - 15%')
plt.plot(Single_sparsemax_val_accuracy_5, label=r'Sparsemax - 5%')
plt.plot(Single_RST_val_accuracy_15, label=r'RST - 15%')
plt.plot(Single_RST_val_accuracy_5, label=r'RST - 5%')
plt.plot(Single_softmax_val_accuracy_15, label=r'Softmax - 15%')
plt.plot(Single_softmax_val_accuracy_5, label=r'Softmax - 5%')
plt.title(r'Single Label Validation Accuracy - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Validation Accuracy (in %) $\longrightarrow$')
plt.legend(loc='best', prop=prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Single_label_val_accuracy_IEEE118.png')
plt.show()

# %%
## Plot results for Multi label accuracy 5% and 15%
plt.plot(Multi_sparsemax_val_accuracy_15, label=r'Sparsemax - 15%')
plt.plot(Multi_sparsemax_val_accuracy_5, label=r'Sparsemax - 5%')
plt.plot(Multi_RST_val_accuracy_15, label=r'RST - 15%')
plt.plot(Multi_RST_val_accuracy_5, label=r'RST - 5%')
plt.plot(Multi_softmax_val_accuracy_15, label=r'Softmax - 15%')
plt.plot(Multi_softmax_val_accuracy_5, label=r'Softmax - 5%')
plt.title(r'Multi Label Validation Accuracy - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Validation Accuracy (in %) $\longrightarrow$')
plt.legend(loc='best', prop=prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Multi_label_val_accuracy_IEEE118.png')
plt.show()

# %%
## Plot results for single label train loss 5% 15%
plt.plot(Single_sparsemax_train_loss_15, label=r'Sparsemax - 15%')
plt.plot(Single_sparsemax_train_loss_5, label=r'Sparsemax - 5%')
plt.plot(Single_RST_train_loss_15, label=r'RST - 15%')
plt.plot(Single_RST_train_loss_5, label=r'RST - 5%')
plt.plot(Single_softmax_train_loss_15, label=r'Softmax - 15%')
plt.plot(Single_softmax_train_loss_5, label=r'Softmax - 5%')
plt.title(r'Single Label Train Loss - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Train Loss $\longrightarrow$')
plt.legend(loc='best', prop=prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Single_label_train_loss_IEEE118.png')
plt.show()

# %%
## Plot results for Multi label train loss 5% and 15%
plt.plot(Multi_sparsemax_train_loss_15, label=r'Sparsemax - 15%')
plt.plot(Multi_sparsemax_train_loss_5, label=r'Sparsemax - 5%')
plt.plot(Multi_RST_train_loss_15, label=r'RST - 15%')
plt.plot(Multi_RST_train_loss_5, label=r'RST - 5%')
plt.plot(Multi_softmax_train_loss_15, label=r'Softmax - 15%')
plt.plot(Multi_softmax_train_loss_5, label=r'Softmax - 5%')
plt.title(r'Multi Label Train Loss - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Train Loss $\longrightarrow$')
plt.legend(loc='best', prop=prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Multi_label_train_loss_IEEE118.png')
plt.show()

# %%
## Plot results for single label train accuracy 5% 15%
plt.plot(Single_sparsemax_train_accuracy_15, label=r'Sparsemax - 15%')
plt.plot(Single_sparsemax_train_accuracy_5, label=r'Sparsemax - 5%')
plt.plot(Single_RST_train_accuracy_15, label=r'RST - 15%')
plt.plot(Single_RST_train_accuracy_5, label=r'RST - 5%')
plt.plot(Single_softmax_train_accuracy_15, label=r'Softmax - 15%')
plt.plot(Single_softmax_train_accuracy_5, label=r'Softmax - 5%')
plt.title(r'Single Label Train Accuracy - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Train Accuracy (in %) $\longrightarrow$')
plt.legend(loc='best', prop=prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Single_label_train_accuracy_IEEE118.png')
plt.show()

# %%
## Plot results for Multi label train accuracy 5% and 15%
plt.plot(Multi_sparsemax_train_accuracy_15, label=r'Sparsemax - 15%')
plt.plot(Multi_sparsemax_train_accuracy_5, label=r'Sparsemax - 5%')
plt.plot(Multi_RST_train_accuracy_15, label=r'RST - 15%')
plt.plot(Multi_RST_train_accuracy_5, label=r'RST - 5%')
plt.plot(Multi_softmax_train_accuracy_15, label=r'Softmax - 15%')
plt.plot(Multi_softmax_train_accuracy_5, label=r'Softmax - 5%')
plt.title(r'Multi Label Train Accuracy - IEEE 118')
plt.xlabel(r'Epochs $\longrightarrow$')
plt.ylabel(r'Train Accuracy (in %) $\longrightarrow$')
plt.legend(loc='best', prop=prop)
plt.grid(True, alpha=0.5)
plt.savefig('./Multi_label_train_accuracy_IEEE118.png')
plt.show()
